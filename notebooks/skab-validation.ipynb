# %% [markdown]
# # SKAB validation
#
# Validate the two detectors (Isolation Forest + LSTM autoencoder) against the public [SKAB](https://github.com/waico/SKAB) dataset. Fill in metric results in the root `README.md` once this runs.
#
# **Scope**
# * Precision / recall / F1 per detector.
# * Detection latency distribution (samples from anomaly onset → first flag).
# * False-positive rate per device-hour.
#
# SKAB channels are multivariate continuous sensor streams — close enough to our
# telemetry shape (4 features, continuous + count) that the model configs port with
# only a feature-count change.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path('..').resolve() / 'detection-service'))

import numpy as np
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support

# %%
# TODO: load SKAB CSVs (clone https://github.com/waico/SKAB into ./skab/)
#   df = pd.concat([pd.read_csv(p, sep=';') for p in pathlib.Path('skab').rglob('*.csv')])
#   features = df[['Accelerometer1RMS', 'Accelerometer2RMS', 'Current', 'Temperature']].values
#   y_true   = df['anomaly'].astype(int).values

# %%
# TODO: fit IForestDetector and LSTMAutoencoderDetector on the normal split,
# score on the full sequence, then compute:
#
#   p, r, f, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')
#
# and the latency histogram (samples from first true=1 to first pred=1 per run).
